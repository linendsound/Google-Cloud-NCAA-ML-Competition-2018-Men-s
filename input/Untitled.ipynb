# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is F828-A577
#
#  Directory of C:\Users\lin\Documents\mycode\kaggle\Google-Cloud-NCAA-ML-Competition-2018-Men-s\Data
#
# 02/23/2018  04:26 PM    <DIR>          .
# 02/23/2018  04:26 PM    <DIR>          ..
# 02/23/2018  04:26 PM    <DIR>          .ipynb_checkpoints
# 02/06/2018  12:40 PM             7,737 Cities.csv
# 02/06/2018  12:41 PM             1,644 Conferences.csv
# 02/06/2018  12:41 PM           120,279 ConferenceTourneyGames.csv
# 02/23/2018  04:16 PM    <DIR>          Events
# 02/06/2018  12:41 PM         1,409,854 GameCities.csv
# 02/02/2018  11:18 AM        70,403,205 MasseyOrdinals.csv
# 02/06/2018  12:41 PM            63,663 NCAATourneyCompactResults.csv
# 02/06/2018  12:41 PM            98,350 NCAATourneyDetailedResults.csv
# 02/06/2018  12:41 PM            14,736 NCAATourneySeedRoundSlots.csv
# 02/06/2018  12:41 PM            32,346 NCAATourneySeeds.csv
# 02/06/2018  12:41 PM            42,340 NCAATourneySlots.csv
# ...

# %%
Team = pd.read_csv('Teams.csv')

# %%
Team.head()
# Out:
#    TeamID     TeamName  FirstD1Season  LastD1Season
# 0    1101  Abilene Chr           2014          2018
# 1    1102    Air Force           1985          2018
# 2    1103        Akron           1985          2018
# 3    1104      Alabama           1985          2018
# 4    1105  Alabama A&M           2000          2018

# %%
Team.LastD1Season.value_counts()
# Out:
# 2018    351
# 1991      2
# 1987      2
# 2011      1
# 2010      1
# 2006      1
# 2003      1
# 1998      1
# 1992      1
# 1990      1
# 1986      1
# 1985      1
# Name: LastD1Season, dtype: int64

# %%
Seasons = pd.read_csv('Seasons.csv')

# %%
Seasons.head()
# Out:
#    Season     DayZero RegionW    RegionX    RegionY    RegionZ
# 0    1985  10/29/1984    East       West    Midwest  Southeast
# 1    1986  10/28/1985    East    Midwest  Southeast       West
# 2    1987  10/27/1986    East  Southeast    Midwest       West
# 3    1988   11/2/1987    East    Midwest  Southeast       West
# 4    1989  10/31/1988    East       West    Midwest  Southeast

# %%
Seasons.RegionW.value_counts()
# Out:
# East           30
# Atlanta         2
# Albuquerque     1
# TBDw            1
# Name: RegionW, dtype: int64

# %%
Seasons.RegionX.value_counts()
# Out:
# Midwest      10
# West          8
# South         8
# Southeast     4
# Oakland       1
# Phoenix       1
# TBDx          1
# Chicago       1
# Name: RegionX, dtype: int64

# %%
a = pd.read_csv('NCAATourneySeeds.csv')

# %%
compact = pd.read_csv('RegularSeasonCompactResults.csv')

# %%
detailed = pd.read_csv('RegularSeasonDetailedResults.csv')

# %%
detailed.columns
# Out:
# Index(['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc',
#        'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR',
#        'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3',
#        'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF'],
#       dtype='object')

# %%
td = pd.read_csv('NCAATourneyCompactResults.csv')

# %%
gc = pd.read_csv('GameCities.csv')

# %%
td.WLoc.value_counts()
# Out:
# N    2117
# Name: WLoc, dtype: int64

# %%
compact.WLoc.value_counts()
# Out:
# H    89564
# A    45933
# N    15187
# Name: WLoc, dtype: int64

# %%
gc.head()
# Out:
#    Season  DayNum  WTeamID  LTeamID   CRType  CityID
# 0    2010       7     1143     1293  Regular    4027
# 1    2010       7     1314     1198  Regular    4061
# 2    2010       7     1326     1108  Regular    4080
# 3    2010       7     1393     1107  Regular    4340
# 4    2010       9     1143     1178  Regular    4027

# %%
mo = pd.read_csv('MasseyOrdinals.csv')

# %%
mo.head()
# Out:
#    Season  RankingDayNum SystemName  TeamID  OrdinalRank
# 0    2003             35        SEL    1102          159
# 1    2003             35        SEL    1103          229
# 2    2003             35        SEL    1104           12
# 3    2003             35        SEL    1105          314
# 4    2003             35        SEL    1106          260

# %%
mo[mo['TeamID']==1102]
# Out:
#          Season  RankingDayNum SystemName  TeamID  OrdinalRank
# 0          2003             35        SEL    1102          159
# 352        2003             37        BIH    1102          122
# 679        2003             37        DUN    1102          112
# 1006       2003             37        ENT    1102          109
# 1333       2003             37        GRN    1102          104
# 1660       2003             37        IMS    1102          131
# 1987       2003             37        MAS    1102           90
# 2314       2003             37        MKV    1102          103
# 2641       2003             37        MOR    1102          110
# 2968       2003             37        POM    1102          104
# 3295       2003             37        RPI    1102          219
# 3622       2003             37        SAG    1102          114
# 3949       2003             37        SAU    1102          112
# 4276       2003             37         SE    1102          119
# ...
